# %%
import pandas as pd
import numpy as np
labels=['a','b','c','d']
list = [1,2,3,4]
dict = {'a':100,'b':200,'c':300,'d':400}
series=pd.Series(list,index=labels)
print(series)
series2=pd.Series(dict)
series2
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64
# a    100
# b    200
# c    300
# d    400
# dtype: int64
