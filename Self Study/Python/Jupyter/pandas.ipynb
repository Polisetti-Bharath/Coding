# %%
import pandas as pd
import numpy as np
labels=['a','b','c','d']
list = [1,2,3,4]
dict = {'a':100,'b':200,'c':300,'d':400}
series=pd.Series(list,index=labels)
print(series)
series2=pd.Series(dict)
series2
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64
# a    100
# b    200
# c    300
# d    400
# dtype: int64

# %% [markdown]
# DataFrame Creation

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df1 = pd.DataFrame(data,index = ['a','b','c','d'])
print(df)
# Out:
#        a   b         c      d
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
data = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df = pd.DataFrame(data,columns=['a','b','c','d'])
print(df)
# Out:
#        a   b         c      d
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
print(df[['a', 'c']])
# Out:
#        a         c
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %%
df1["Job"]=["Doctor","Engineer","Scientist","Teacher"]

# %%
df1
# Out:
#     Name  Age      City  Salary        Job
# a   John   28  New York   65000     Doctor
# b   Anna   34     Paris   70000   Engineer
# c  Peter   29    Berlin   62000  Scientist
# d  Linda   42    London   85000    Teacher

# %%
df1 = df1.drop("a",axis=0)
df1
# Out:
#     Name  Age    City  Salary
# b   Anna   34   Paris   70000
# c  Peter   29  Berlin   62000
# d  Linda   42  London   85000
